# %%
import pandas as pd
df=pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9465  2023-10-03  320.829987  321.390015  311.209991  313.390015  313.390015
# 9466  2023-10-04  314.029999  320.040009  314.000000  318.959991  318.959991
# 9467  2023-10-05  319.089996  319.980011  314.899994  319.359985  319.359985
# 9468  2023-10-06  316.549988  329.190002  316.299988  327.260010  327.260010
# 9469  2023-10-09  324.750000  330.299988  323.179993  329.820007  329.820007
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9465    21033500
# 9466    20720100
# 9467    16965600
# 9468    25645500
# 9469    19869600
#
# [9470 rows x 7 columns]

# %%
df =df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9465    2023-10-03
# 9466    2023-10-04
# 9467    2023-10-05
# 9468    2023-10-06
# 9469    2023-10-09
# Name: Date, Length: 9470, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']= df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\DEV\AppData\Local\Temp\ipykernel_12464\1066266531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9465   2023-10-03
# 9466   2023-10-04
# 9467   2023-10-05
# 9468   2023-10-06
# 9469   2023-10-09
# Name: Date, Length: 9470, dtype: datetime64[ns]

# %%
df.index=df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-03  313.390015
# 2023-10-04  318.959991
# 2023-10-05  319.359985
# 2023-10-06  327.260010
# 2023-10-09  329.820007
#
# [9470 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 11s 382ms/step - loss: 84846.7500 - mean_absolute_error: 289.5444 - val_loss: 92444.9062 - val_mean_absolute_error: 303.9604
# Epoch 2/100
# 7/7 [==============================] - 0s 22ms/step - loss: 84473.6797 - mean_absolute_error: 288.9008 - val_loss: 92111.9609 - val_mean_absolute_error: 303.4122
# Epoch 3/100
# 7/7 [==============================] - 0s 22ms/step - loss: 84177.0547 - mean_absolute_error: 288.3858 - val_loss: 91819.4062 - val_mean_absolute_error: 302.9297
# Epoch 4/100
# 7/7 [==============================] - 0s 23ms/step - loss: 83882.8672 - mean_absolute_error: 287.8737 - val_loss: 91473.7578 - val_mean_absolute_error: 302.3587
# Epoch 5/100
# 7/7 [==============================] - 0s 24ms/step - loss: 83546.0234 - mean_absolute_error: 287.2914 - val_loss: 91090.3125 - val_mean_absolute_error: 301.7239
# Epoch 6/100
# 7/7 [==============================] - 0s 22ms/step - loss: 83116.5000 - mean_absolute_error: 286.5401 - val_loss: 90498.2422 - val_mean_absolute_error: 300.7412
# Epoch 7/100
# 7/7 [==============================] - 0s 21ms/step - loss: 82500.7422 - mean_absolute_error: 285.4655 - val_loss: 89795.1797 - val_mean_absolute_error: 299.5700
# Epoch 8/100
# 7/7 [==============================] - 0s 20ms/step - loss: 81778.2266 - mean_absolute_error: 284.1943 - val_loss: 88903.4688 - val_mean_absolute_error: 298.0780
# Epoch 9/100
# 7/7 [==============================] - 0s 21ms/step - loss: 80861.2578 - mean_absolute_error: 282.5856 - val_loss: 87870.2734 - val_mean_absolute_error: 296.3398
# Epoch 10/100
# 7/7 [==============================] - 0s 23ms/step - loss: 79836.8125 - mean_absolute_error: 280.7563 - val_loss: 86656.6016 - val_mean_absolute_error: 294.2849
# Epoch 11/100
# 7/7 [==============================] - 0s 21ms/step - loss: 78525.2500 - mean_absolute_error: 278.4139 - val_loss: 84961.2188 - val_mean_absolute_error: 291.3901
# Epoch 12/100
# 7/7 [==============================] - 0s 23ms/step - loss: 76751.0625 - mean_absolute_error: 275.2073 - val_loss: 82908.5000 - val_mean_absolute_error: 287.8463
# Epoch 13/100
# 7/7 [==============================] - 0s 25ms/step - loss: 74672.1172 - mean_absolute_error: 271.4080 - val_loss: 80399.1094 - val_mean_absolute_error: 283.4539
# Epoch 14/100
# 7/7 [==============================] - 0s 24ms/step - loss: 72155.8594 - mean_absolute_error: 266.7216 - val_loss: 77377.8281 - val_mean_absolute_error: 278.0733
# Epoch 15/100
# 7/7 [==============================] - 0s 22ms/step - loss: 69059.0859 - mean_absolute_error: 260.8669 - val_loss: 73980.6250 - val_mean_absolute_error: 271.8964
# Epoch 16/100
# 7/7 [==============================] - 0s 22ms/step - loss: 65819.6641 - mean_absolute_error: 254.5784 - val_loss: 70367.6875 - val_mean_absolute_error: 265.1693
# Epoch 17/100
# 7/7 [==============================] - 0s 23ms/step - loss: 62266.5625 - mean_absolute_error: 247.4952 - val_loss: 66351.8828 - val_mean_absolute_error: 257.4857
# Epoch 18/100
# 7/7 [==============================] - 0s 24ms/step - loss: 58337.2422 - mean_absolute_error: 239.3831 - val_loss: 61816.4102 - val_mean_absolute_error: 248.5223
# Epoch 19/100
# 7/7 [==============================] - 0s 20ms/step - loss: 53681.5938 - mean_absolute_error: 229.4977 - val_loss: 56370.2617 - val_mean_absolute_error: 237.3126
# Epoch 20/100
# 7/7 [==============================] - 0s 18ms/step - loss: 48565.7148 - mean_absolute_error: 218.0629 - val_loss: 50843.7539 - val_mean_absolute_error: 225.3679
# Epoch 21/100
# 7/7 [==============================] - 0s 18ms/step - loss: 43238.8320 - mean_absolute_error: 205.4518 - val_loss: 44953.3086 - val_mean_absolute_error: 211.8970
# Epoch 22/100
# 7/7 [==============================] - 0s 17ms/step - loss: 37746.0820 - mean_absolute_error: 191.6767 - val_loss: 39036.5156 - val_mean_absolute_error: 197.4425
# Epoch 23/100
# 7/7 [==============================] - 0s 21ms/step - loss: 32264.9922 - mean_absolute_error: 176.7117 - val_loss: 32997.2734 - val_mean_absolute_error: 181.5051
# Epoch 24/100
# 7/7 [==============================] - 0s 23ms/step - loss: 26520.3926 - mean_absolute_error: 159.6235 - val_loss: 26691.0508 - val_mean_absolute_error: 163.2118
# Epoch 25/100
# 7/7 [==============================] - 0s 28ms/step - loss: 21098.6016 - mean_absolute_error: 141.6100 - val_loss: 21146.7207 - val_mean_absolute_error: 145.2369
# Epoch 26/100
# 7/7 [==============================] - 0s 59ms/step - loss: 16274.5684 - mean_absolute_error: 123.3500 - val_loss: 16085.8936 - val_mean_absolute_error: 126.6211
# Epoch 27/100
# 7/7 [==============================] - 0s 46ms/step - loss: 11931.3682 - mean_absolute_error: 104.4049 - val_loss: 11401.8877 - val_mean_absolute_error: 106.5303
# Epoch 28/100
# 7/7 [==============================] - 0s 18ms/step - loss: 8119.9814 - mean_absolute_error: 84.1598 - val_loss: 7676.5225 - val_mean_absolute_error: 87.3130
# Epoch 29/100
# 7/7 [==============================] - 0s 23ms/step - loss: 5345.0654 - mean_absolute_error: 65.6038 - val_loss: 4900.7207 - val_mean_absolute_error: 69.6258
# Epoch 30/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3390.3088 - mean_absolute_error: 48.9071 - val_loss: 2967.8062 - val_mean_absolute_error: 53.9892
# Epoch 31/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2145.9192 - mean_absolute_error: 37.2329 - val_loss: 1681.9237 - val_mean_absolute_error: 40.3585
# Epoch 32/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1447.9812 - mean_absolute_error: 31.6038 - val_loss: 915.9926 - val_mean_absolute_error: 29.3773
# Epoch 33/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1139.6903 - mean_absolute_error: 28.4784 - val_loss: 520.4870 - val_mean_absolute_error: 21.6222
# Epoch 34/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1037.3927 - mean_absolute_error: 27.2189 - val_loss: 319.5254 - val_mean_absolute_error: 16.3267
# Epoch 35/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1017.4546 - mean_absolute_error: 26.9413 - val_loss: 235.7494 - val_mean_absolute_error: 13.6960
# Epoch 36/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1013.1580 - mean_absolute_error: 26.9065 - val_loss: 217.3553 - val_mean_absolute_error: 13.0536
# Epoch 37/100
# 7/7 [==============================] - 0s 27ms/step - loss: 1014.0299 - mean_absolute_error: 26.9242 - val_loss: 218.9331 - val_mean_absolute_error: 13.1100
# Epoch 38/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1013.3895 - mean_absolute_error: 26.9197 - val_loss: 231.4512 - val_mean_absolute_error: 13.5489
# Epoch 39/100
# 7/7 [==============================] - 0s 33ms/step - loss: 1012.1863 - mean_absolute_error: 26.9083 - val_loss: 243.6819 - val_mean_absolute_error: 13.9630
# Epoch 40/100
# 7/7 [==============================] - 0s 33ms/step - loss: 1010.8983 - mean_absolute_error: 26.8822 - val_loss: 247.4590 - val_mean_absolute_error: 14.0882
# Epoch 41/100
# 7/7 [==============================] - 0s 28ms/step - loss: 1010.8513 - mean_absolute_error: 26.8700 - val_loss: 267.1580 - val_mean_absolute_error: 14.7223
# Epoch 42/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1010.1787 - mean_absolute_error: 26.8621 - val_loss: 289.1020 - val_mean_absolute_error: 15.3952
# Epoch 43/100
# 7/7 [==============================] - 0s 19ms/step - loss: 1011.8951 - mean_absolute_error: 26.8813 - val_loss: 309.2326 - val_mean_absolute_error: 16.0084
# Epoch 44/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1011.3818 - mean_absolute_error: 26.8878 - val_loss: 307.9369 - val_mean_absolute_error: 15.9679
# Epoch 45/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1011.2897 - mean_absolute_error: 26.8871 - val_loss: 303.6499 - val_mean_absolute_error: 15.8331
# Epoch 46/100
# 7/7 [==============================] - 0s 26ms/step - loss: 1010.9164 - mean_absolute_error: 26.8705 - val_loss: 294.3753 - val_mean_absolute_error: 15.5522
# Epoch 47/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1010.1968 - mean_absolute_error: 26.8651 - val_loss: 282.2142 - val_mean_absolute_error: 15.1876
# Epoch 48/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1008.8579 - mean_absolute_error: 26.8452 - val_loss: 278.7044 - val_mean_absolute_error: 15.0845
# Epoch 49/100
# 7/7 [==============================] - 0s 20ms/step - loss: 995.0372 - mean_absolute_error: 26.6875 - val_loss: 300.8860 - val_mean_absolute_error: 15.7755
# Epoch 50/100
# 7/7 [==============================] - 0s 20ms/step - loss: 981.5631 - mean_absolute_error: 26.4853 - val_loss: 278.1927 - val_mean_absolute_error: 15.0855
# Epoch 51/100
# 7/7 [==============================] - 0s 18ms/step - loss: 976.2536 - mean_absolute_error: 26.3944 - val_loss: 290.1274 - val_mean_absolute_error: 15.4507
# Epoch 52/100
# 7/7 [==============================] - 0s 18ms/step - loss: 974.5651 - mean_absolute_error: 26.4174 - val_loss: 269.3838 - val_mean_absolute_error: 14.8231
# Epoch 53/100
# 7/7 [==============================] - 0s 21ms/step - loss: 965.7917 - mean_absolute_error: 26.2842 - val_loss: 261.4244 - val_mean_absolute_error: 14.5743
# Epoch 54/100
# 7/7 [==============================] - 0s 21ms/step - loss: 959.3328 - mean_absolute_error: 26.1721 - val_loss: 303.0800 - val_mean_absolute_error: 15.8886
# Epoch 55/100
# 7/7 [==============================] - 0s 20ms/step - loss: 968.8735 - mean_absolute_error: 26.2295 - val_loss: 302.3218 - val_mean_absolute_error: 15.8897
# Epoch 56/100
# 7/7 [==============================] - 0s 24ms/step - loss: 888.1066 - mean_absolute_error: 25.0964 - val_loss: 196.9185 - val_mean_absolute_error: 12.3707
# Epoch 57/100
# 7/7 [==============================] - 0s 23ms/step - loss: 845.5825 - mean_absolute_error: 24.4532 - val_loss: 405.0475 - val_mean_absolute_error: 18.9668
# Epoch 58/100
# 7/7 [==============================] - 0s 22ms/step - loss: 780.3865 - mean_absolute_error: 23.5180 - val_loss: 301.7113 - val_mean_absolute_error: 16.0147
# Epoch 59/100
# 7/7 [==============================] - 0s 23ms/step - loss: 748.1060 - mean_absolute_error: 22.9948 - val_loss: 191.4200 - val_mean_absolute_error: 12.2580
# Epoch 60/100
# 7/7 [==============================] - 0s 23ms/step - loss: 717.8846 - mean_absolute_error: 22.6366 - val_loss: 162.0687 - val_mean_absolute_error: 11.0986
# Epoch 61/100
# 7/7 [==============================] - 0s 22ms/step - loss: 698.9114 - mean_absolute_error: 22.2901 - val_loss: 217.0074 - val_mean_absolute_error: 13.2730
# Epoch 62/100
# 7/7 [==============================] - 0s 23ms/step - loss: 614.4512 - mean_absolute_error: 20.6678 - val_loss: 147.7647 - val_mean_absolute_error: 10.5685
# Epoch 63/100
# 7/7 [==============================] - 0s 25ms/step - loss: 580.7634 - mean_absolute_error: 20.0048 - val_loss: 123.8927 - val_mean_absolute_error: 9.4471
# Epoch 64/100
# 7/7 [==============================] - 0s 22ms/step - loss: 542.2775 - mean_absolute_error: 19.5366 - val_loss: 124.6937 - val_mean_absolute_error: 9.5561
# Epoch 65/100
# 7/7 [==============================] - 0s 22ms/step - loss: 556.6512 - mean_absolute_error: 19.4073 - val_loss: 178.9274 - val_mean_absolute_error: 11.9619
# Epoch 66/100
# 7/7 [==============================] - 0s 23ms/step - loss: 481.4843 - mean_absolute_error: 18.3109 - val_loss: 171.6207 - val_mean_absolute_error: 11.7034
# Epoch 67/100
# 7/7 [==============================] - 0s 22ms/step - loss: 418.6380 - mean_absolute_error: 16.8911 - val_loss: 188.9124 - val_mean_absolute_error: 12.4245
# Epoch 68/100
# 7/7 [==============================] - 0s 21ms/step - loss: 378.7112 - mean_absolute_error: 15.9762 - val_loss: 83.3510 - val_mean_absolute_error: 7.5496
# Epoch 69/100
# 7/7 [==============================] - 0s 21ms/step - loss: 411.9573 - mean_absolute_error: 17.4230 - val_loss: 218.8975 - val_mean_absolute_error: 13.6234
# Epoch 70/100
# 7/7 [==============================] - 0s 18ms/step - loss: 334.2825 - mean_absolute_error: 15.4381 - val_loss: 389.8978 - val_mean_absolute_error: 18.8545
# Epoch 71/100
# 7/7 [==============================] - 0s 21ms/step - loss: 329.9356 - mean_absolute_error: 14.6845 - val_loss: 156.8334 - val_mean_absolute_error: 11.1607
# Epoch 72/100
# 7/7 [==============================] - 0s 21ms/step - loss: 246.0843 - mean_absolute_error: 12.6931 - val_loss: 82.5021 - val_mean_absolute_error: 7.5715
# Epoch 73/100
# 7/7 [==============================] - 0s 21ms/step - loss: 220.2293 - mean_absolute_error: 11.8085 - val_loss: 55.3678 - val_mean_absolute_error: 6.0504
# Epoch 74/100
# 7/7 [==============================] - 0s 22ms/step - loss: 227.4905 - mean_absolute_error: 12.1262 - val_loss: 33.9893 - val_mean_absolute_error: 5.0019
# Epoch 75/100
# 7/7 [==============================] - 0s 21ms/step - loss: 182.6509 - mean_absolute_error: 10.9737 - val_loss: 33.9623 - val_mean_absolute_error: 4.9188
# Epoch 76/100
# 7/7 [==============================] - 0s 22ms/step - loss: 160.2687 - mean_absolute_error: 10.0801 - val_loss: 59.7491 - val_mean_absolute_error: 6.3220
# Epoch 77/100
# 7/7 [==============================] - 0s 23ms/step - loss: 149.6769 - mean_absolute_error: 9.9593 - val_loss: 53.7774 - val_mean_absolute_error: 6.0092
# Epoch 78/100
# 7/7 [==============================] - 0s 22ms/step - loss: 145.2283 - mean_absolute_error: 10.0253 - val_loss: 53.6858 - val_mean_absolute_error: 5.9743
# Epoch 79/100
# 7/7 [==============================] - 0s 23ms/step - loss: 116.1604 - mean_absolute_error: 9.0884 - val_loss: 38.4196 - val_mean_absolute_error: 5.2197
# Epoch 80/100
# 7/7 [==============================] - 0s 23ms/step - loss: 97.6328 - mean_absolute_error: 7.9608 - val_loss: 32.3547 - val_mean_absolute_error: 4.9220
# Epoch 81/100
# 7/7 [==============================] - 0s 24ms/step - loss: 94.0917 - mean_absolute_error: 8.0007 - val_loss: 30.7992 - val_mean_absolute_error: 4.8522
# Epoch 82/100
# 7/7 [==============================] - 0s 22ms/step - loss: 80.1901 - mean_absolute_error: 7.3849 - val_loss: 69.7567 - val_mean_absolute_error: 6.7451
# Epoch 83/100
# 7/7 [==============================] - 0s 22ms/step - loss: 69.2273 - mean_absolute_error: 6.4357 - val_loss: 100.8161 - val_mean_absolute_error: 8.3963
# Epoch 84/100
# 7/7 [==============================] - 0s 22ms/step - loss: 82.9811 - mean_absolute_error: 7.4747 - val_loss: 102.4367 - val_mean_absolute_error: 8.4905
# Epoch 85/100
# 7/7 [==============================] - 0s 21ms/step - loss: 77.1183 - mean_absolute_error: 7.4323 - val_loss: 66.7521 - val_mean_absolute_error: 6.5727
# Epoch 86/100
# 7/7 [==============================] - 0s 24ms/step - loss: 50.6323 - mean_absolute_error: 5.7219 - val_loss: 45.9059 - val_mean_absolute_error: 5.4800
# Epoch 87/100
# 7/7 [==============================] - 0s 25ms/step - loss: 40.5516 - mean_absolute_error: 5.0035 - val_loss: 90.2727 - val_mean_absolute_error: 7.8857
# Epoch 88/100
# 7/7 [==============================] - 0s 23ms/step - loss: 47.7191 - mean_absolute_error: 5.8064 - val_loss: 71.3955 - val_mean_absolute_error: 6.8619
# Epoch 89/100
# 7/7 [==============================] - 0s 24ms/step - loss: 42.1654 - mean_absolute_error: 5.0381 - val_loss: 42.6148 - val_mean_absolute_error: 5.3538
# Epoch 90/100
# 7/7 [==============================] - 0s 20ms/step - loss: 30.2953 - mean_absolute_error: 4.2630 - val_loss: 35.3885 - val_mean_absolute_error: 4.9035
# Epoch 91/100
# 7/7 [==============================] - 0s 22ms/step - loss: 26.4846 - mean_absolute_error: 4.0412 - val_loss: 34.5777 - val_mean_absolute_error: 4.8261
# Epoch 92/100
# 7/7 [==============================] - 0s 22ms/step - loss: 27.7715 - mean_absolute_error: 4.2000 - val_loss: 53.7528 - val_mean_absolute_error: 6.0718
# Epoch 93/100
# 7/7 [==============================] - 0s 23ms/step - loss: 28.0844 - mean_absolute_error: 4.1741 - val_loss: 34.6064 - val_mean_absolute_error: 4.8076
# Epoch 94/100
# 7/7 [==============================] - 0s 25ms/step - loss: 32.9896 - mean_absolute_error: 4.7691 - val_loss: 37.4646 - val_mean_absolute_error: 4.9136
# Epoch 95/100
# 7/7 [==============================] - 0s 24ms/step - loss: 29.9273 - mean_absolute_error: 4.5549 - val_loss: 35.8121 - val_mean_absolute_error: 4.8906
# Epoch 96/100
# 7/7 [==============================] - 0s 24ms/step - loss: 26.9088 - mean_absolute_error: 4.0762 - val_loss: 53.6146 - val_mean_absolute_error: 6.0790
# Epoch 97/100
# 7/7 [==============================] - 0s 23ms/step - loss: 21.9495 - mean_absolute_error: 3.7520 - val_loss: 54.3893 - val_mean_absolute_error: 6.1305
# Epoch 98/100
# 7/7 [==============================] - 0s 23ms/step - loss: 22.5073 - mean_absolute_error: 3.7759 - val_loss: 58.6209 - val_mean_absolute_error: 6.3423
# Epoch 99/100
# 7/7 [==============================] - 0s 23ms/step - loss: 22.8794 - mean_absolute_error: 3.7734 - val_loss: 47.5046 - val_mean_absolute_error: 5.7686
# Epoch 100/100
# 7/7 [==============================] - 0s 24ms/step - loss: 20.1480 - mean_absolute_error: 3.6063 - val_loss: 35.3485 - val_mean_absolute_error: 4.7148

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 6ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 62ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

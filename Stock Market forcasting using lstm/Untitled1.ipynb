# %%
import pandas as pd
df=pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9465  2023-10-03  320.829987  321.390015  311.209991  313.390015  313.390015
# 9466  2023-10-04  314.029999  320.040009  314.000000  318.959991  318.959991
# 9467  2023-10-05  319.089996  319.980011  314.899994  319.359985  319.359985
# 9468  2023-10-06  316.549988  329.190002  316.299988  327.260010  327.260010
# 9469  2023-10-09  324.750000  330.299988  323.179993  329.820007  329.820007
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9465    21033500
# 9466    20720100
# 9467    16965600
# 9468    25645500
# 9469    19869600
#
# [9470 rows x 7 columns]

# %%
df =df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9465    2023-10-03
# 9466    2023-10-04
# 9467    2023-10-05
# 9468    2023-10-06
# 9469    2023-10-09
# Name: Date, Length: 9470, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']= df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\DEV\AppData\Local\Temp\ipykernel_11696\1066266531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9465   2023-10-03
# 9466   2023-10-04
# 9467   2023-10-05
# 9468   2023-10-06
# 9469   2023-10-09
# Name: Date, Length: 9470, dtype: datetime64[ns]

# %%
df.index=df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-03  313.390015
# 2023-10-04  318.959991
# 2023-10-05  319.359985
# 2023-10-06  327.260010
# 2023-10-09  329.820007
#
# [9470 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 235ms/step - loss: 84680.7266 - mean_absolute_error: 289.2583 - val_loss: 92418.7266 - val_mean_absolute_error: 303.9174
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 84498.8047 - mean_absolute_error: 288.9452 - val_loss: 92198.7891 - val_mean_absolute_error: 303.5553
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: 84244.4062 - mean_absolute_error: 288.5035 - val_loss: 91847.7812 - val_mean_absolute_error: 302.9766
# Epoch 4/100
# 7/7 [==============================] - 0s 11ms/step - loss: 83919.8984 - mean_absolute_error: 287.9388 - val_loss: 91533.8594 - val_mean_absolute_error: 302.4581
# Epoch 5/100
# 7/7 [==============================] - 0s 14ms/step - loss: 83600.5781 - mean_absolute_error: 287.3857 - val_loss: 91138.6719 - val_mean_absolute_error: 301.8040
# Epoch 6/100
# 7/7 [==============================] - 0s 13ms/step - loss: 83142.1484 - mean_absolute_error: 286.5797 - val_loss: 90479.2969 - val_mean_absolute_error: 300.7096
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 82388.5078 - mean_absolute_error: 285.2662 - val_loss: 89557.3672 - val_mean_absolute_error: 299.1729
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 81547.4375 - mean_absolute_error: 283.7877 - val_loss: 88638.3984 - val_mean_absolute_error: 297.6329
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80460.1719 - mean_absolute_error: 281.8586 - val_loss: 87096.3828 - val_mean_absolute_error: 295.0312
# Epoch 10/100
# 7/7 [==============================] - 0s 13ms/step - loss: 78936.1328 - mean_absolute_error: 279.1557 - val_loss: 85535.2422 - val_mean_absolute_error: 292.3735
# Epoch 11/100
# 7/7 [==============================] - 0s 12ms/step - loss: 77387.3359 - mean_absolute_error: 276.3613 - val_loss: 83661.6641 - val_mean_absolute_error: 289.1516
# Epoch 12/100
# 7/7 [==============================] - 0s 13ms/step - loss: 75377.2969 - mean_absolute_error: 272.6911 - val_loss: 81090.5938 - val_mean_absolute_error: 284.6709
# Epoch 13/100
# 7/7 [==============================] - 0s 14ms/step - loss: 72760.0234 - mean_absolute_error: 267.8495 - val_loss: 78216.5547 - val_mean_absolute_error: 279.5774
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 69901.7344 - mean_absolute_error: 262.4771 - val_loss: 74866.6641 - val_mean_absolute_error: 273.5209
# Epoch 15/100
# 7/7 [==============================] - 0s 14ms/step - loss: 66713.8828 - mean_absolute_error: 256.3184 - val_loss: 71413.6250 - val_mean_absolute_error: 267.1342
# Epoch 16/100
# 7/7 [==============================] - 0s 13ms/step - loss: 63326.1953 - mean_absolute_error: 249.6342 - val_loss: 67617.5000 - val_mean_absolute_error: 259.9318
# Epoch 17/100
# 7/7 [==============================] - 0s 11ms/step - loss: 59631.2422 - mean_absolute_error: 242.0886 - val_loss: 63469.6367 - val_mean_absolute_error: 251.8267
# Epoch 18/100
# 7/7 [==============================] - 0s 15ms/step - loss: 55587.9805 - mean_absolute_error: 233.6494 - val_loss: 59009.3906 - val_mean_absolute_error: 242.8094
# Epoch 19/100
# 7/7 [==============================] - 0s 15ms/step - loss: 51270.6797 - mean_absolute_error: 224.1597 - val_loss: 54019.8008 - val_mean_absolute_error: 232.3075
# Epoch 20/100
# 7/7 [==============================] - 0s 15ms/step - loss: 46370.0664 - mean_absolute_error: 212.9366 - val_loss: 48520.6602 - val_mean_absolute_error: 220.1536
# Epoch 21/100
# 7/7 [==============================] - 0s 16ms/step - loss: 41262.5000 - mean_absolute_error: 200.5953 - val_loss: 43196.6758 - val_mean_absolute_error: 207.7106
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 36336.4297 - mean_absolute_error: 187.9577 - val_loss: 37914.2344 - val_mean_absolute_error: 194.5797
# Epoch 23/100
# 7/7 [==============================] - 0s 14ms/step - loss: 31463.5977 - mean_absolute_error: 174.5192 - val_loss: 32692.4023 - val_mean_absolute_error: 180.6639
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 26732.5742 - mean_absolute_error: 160.3356 - val_loss: 27638.2266 - val_mean_absolute_error: 166.0881
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 22210.3574 - mean_absolute_error: 145.5918 - val_loss: 22881.4668 - val_mean_absolute_error: 151.0910
# Epoch 26/100
# 7/7 [==============================] - 0s 13ms/step - loss: 18046.5059 - mean_absolute_error: 130.4307 - val_loss: 18465.5176 - val_mean_absolute_error: 135.6925
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14069.9971 - mean_absolute_error: 114.1775 - val_loss: 13815.6445 - val_mean_absolute_error: 117.3139
# Epoch 28/100
# 7/7 [==============================] - 0s 14ms/step - loss: 10295.3418 - mean_absolute_error: 96.3379 - val_loss: 10347.8115 - val_mean_absolute_error: 101.4635
# Epoch 29/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7547.9883 - mean_absolute_error: 80.6932 - val_loss: 7351.7305 - val_mean_absolute_error: 85.4300
# Epoch 30/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5128.0664 - mean_absolute_error: 64.0031 - val_loss: 4883.1851 - val_mean_absolute_error: 69.4998
# Epoch 31/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3461.2656 - mean_absolute_error: 49.7850 - val_loss: 3205.7927 - val_mean_absolute_error: 56.1499
# Epoch 32/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2353.3403 - mean_absolute_error: 39.1731 - val_loss: 1906.2389 - val_mean_absolute_error: 43.0482
# Epoch 33/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1567.8203 - mean_absolute_error: 32.5848 - val_loss: 1091.4763 - val_mean_absolute_error: 32.2260
# Epoch 34/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1214.3231 - mean_absolute_error: 29.4479 - val_loss: 638.5939 - val_mean_absolute_error: 24.1999
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1066.1456 - mean_absolute_error: 27.5976 - val_loss: 406.2458 - val_mean_absolute_error: 18.8002
# Epoch 36/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1013.1674 - mean_absolute_error: 26.9687 - val_loss: 297.6720 - val_mean_absolute_error: 15.6573
# Epoch 37/100
# 7/7 [==============================] - 0s 14ms/step - loss: 998.5475 - mean_absolute_error: 26.7162 - val_loss: 249.3316 - val_mean_absolute_error: 14.1616
# Epoch 38/100
# 7/7 [==============================] - 0s 13ms/step - loss: 999.9042 - mean_absolute_error: 26.7258 - val_loss: 229.4094 - val_mean_absolute_error: 13.4927
# Epoch 39/100
# 7/7 [==============================] - 0s 14ms/step - loss: 995.1461 - mean_absolute_error: 26.6863 - val_loss: 259.6559 - val_mean_absolute_error: 14.4953
# Epoch 40/100
# 7/7 [==============================] - 0s 14ms/step - loss: 994.1020 - mean_absolute_error: 26.6452 - val_loss: 247.5462 - val_mean_absolute_error: 14.1070
# Epoch 41/100
# 7/7 [==============================] - 0s 12ms/step - loss: 990.4417 - mean_absolute_error: 26.6090 - val_loss: 242.5851 - val_mean_absolute_error: 13.9483
# Epoch 42/100
# 7/7 [==============================] - 0s 13ms/step - loss: 964.2447 - mean_absolute_error: 26.2033 - val_loss: 256.8554 - val_mean_absolute_error: 14.4212
# Epoch 43/100
# 7/7 [==============================] - 0s 14ms/step - loss: 980.5202 - mean_absolute_error: 26.4716 - val_loss: 224.8640 - val_mean_absolute_error: 13.3386
# Epoch 44/100
# 7/7 [==============================] - 0s 14ms/step - loss: 985.3700 - mean_absolute_error: 26.5334 - val_loss: 244.9119 - val_mean_absolute_error: 14.0251
# Epoch 45/100
# 7/7 [==============================] - 0s 14ms/step - loss: 983.5571 - mean_absolute_error: 26.5188 - val_loss: 237.4724 - val_mean_absolute_error: 13.7778
# Epoch 46/100
# 7/7 [==============================] - 0s 15ms/step - loss: 981.4059 - mean_absolute_error: 26.4806 - val_loss: 234.8380 - val_mean_absolute_error: 13.6896
# Epoch 47/100
# 7/7 [==============================] - 0s 14ms/step - loss: 979.5071 - mean_absolute_error: 26.4517 - val_loss: 241.2008 - val_mean_absolute_error: 13.9061
# Epoch 48/100
# 7/7 [==============================] - 0s 14ms/step - loss: 977.1390 - mean_absolute_error: 26.4189 - val_loss: 252.1645 - val_mean_absolute_error: 14.2691
# Epoch 49/100
# 7/7 [==============================] - 0s 14ms/step - loss: 974.7528 - mean_absolute_error: 26.3840 - val_loss: 254.1131 - val_mean_absolute_error: 14.3338
# Epoch 50/100
# 7/7 [==============================] - 0s 14ms/step - loss: 971.0851 - mean_absolute_error: 26.3283 - val_loss: 304.9171 - val_mean_absolute_error: 15.9309
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 956.9901 - mean_absolute_error: 26.1408 - val_loss: 276.0312 - val_mean_absolute_error: 15.0361
# Epoch 52/100
# 7/7 [==============================] - 0s 12ms/step - loss: 952.2296 - mean_absolute_error: 26.0671 - val_loss: 280.6609 - val_mean_absolute_error: 15.1835
# Epoch 53/100
# 7/7 [==============================] - 0s 15ms/step - loss: 946.4448 - mean_absolute_error: 26.0073 - val_loss: 261.3547 - val_mean_absolute_error: 14.5881
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 949.6282 - mean_absolute_error: 26.0355 - val_loss: 273.5592 - val_mean_absolute_error: 14.9754
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 926.2938 - mean_absolute_error: 25.7050 - val_loss: 321.1574 - val_mean_absolute_error: 16.4710
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 901.1851 - mean_absolute_error: 25.3497 - val_loss: 242.8812 - val_mean_absolute_error: 14.0193
# Epoch 57/100
# 7/7 [==============================] - 0s 14ms/step - loss: 888.5724 - mean_absolute_error: 25.1749 - val_loss: 336.1971 - val_mean_absolute_error: 16.9636
# Epoch 58/100
# 7/7 [==============================] - 0s 13ms/step - loss: 877.1661 - mean_absolute_error: 25.0379 - val_loss: 239.8126 - val_mean_absolute_error: 13.9411
# Epoch 59/100
# 7/7 [==============================] - 0s 14ms/step - loss: 855.7315 - mean_absolute_error: 24.7136 - val_loss: 281.0572 - val_mean_absolute_error: 15.2873
# Epoch 60/100
# 7/7 [==============================] - 0s 13ms/step - loss: 849.3694 - mean_absolute_error: 24.7111 - val_loss: 209.8732 - val_mean_absolute_error: 12.9229
# Epoch 61/100
# 7/7 [==============================] - 0s 16ms/step - loss: 820.6762 - mean_absolute_error: 24.1949 - val_loss: 227.8754 - val_mean_absolute_error: 13.5780
# Epoch 62/100
# 7/7 [==============================] - 0s 13ms/step - loss: 778.9011 - mean_absolute_error: 23.5518 - val_loss: 653.9656 - val_mean_absolute_error: 24.7137
# Epoch 63/100
# 7/7 [==============================] - 0s 11ms/step - loss: 732.8152 - mean_absolute_error: 22.6442 - val_loss: 204.9626 - val_mean_absolute_error: 12.8162
# Epoch 64/100
# 7/7 [==============================] - 0s 13ms/step - loss: 653.3425 - mean_absolute_error: 21.5231 - val_loss: 165.4756 - val_mean_absolute_error: 11.3024
# Epoch 65/100
# 7/7 [==============================] - 0s 13ms/step - loss: 659.4949 - mean_absolute_error: 21.5674 - val_loss: 154.0722 - val_mean_absolute_error: 10.8482
# Epoch 66/100
# 7/7 [==============================] - 0s 14ms/step - loss: 591.3569 - mean_absolute_error: 20.4362 - val_loss: 213.6023 - val_mean_absolute_error: 13.2125
# Epoch 67/100
# 7/7 [==============================] - 0s 13ms/step - loss: 536.6143 - mean_absolute_error: 19.5058 - val_loss: 348.9733 - val_mean_absolute_error: 17.6389
# Epoch 68/100
# 7/7 [==============================] - 0s 13ms/step - loss: 529.8322 - mean_absolute_error: 19.3717 - val_loss: 379.3430 - val_mean_absolute_error: 18.4816
# Epoch 69/100
# 7/7 [==============================] - 0s 12ms/step - loss: 479.1898 - mean_absolute_error: 17.9992 - val_loss: 94.6037 - val_mean_absolute_error: 8.0891
# Epoch 70/100
# 7/7 [==============================] - 0s 13ms/step - loss: 443.1561 - mean_absolute_error: 17.5916 - val_loss: 175.5129 - val_mean_absolute_error: 11.8711
# Epoch 71/100
# 7/7 [==============================] - 0s 15ms/step - loss: 408.3032 - mean_absolute_error: 16.7830 - val_loss: 113.8679 - val_mean_absolute_error: 9.1610
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 375.9626 - mean_absolute_error: 16.1633 - val_loss: 100.2248 - val_mean_absolute_error: 8.4983
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 359.2520 - mean_absolute_error: 15.8990 - val_loss: 290.1251 - val_mean_absolute_error: 16.0273
# Epoch 74/100
# 7/7 [==============================] - 0s 11ms/step - loss: 328.7400 - mean_absolute_error: 14.9109 - val_loss: 127.8193 - val_mean_absolute_error: 9.8893
# Epoch 75/100
# 7/7 [==============================] - 0s 15ms/step - loss: 275.8272 - mean_absolute_error: 13.4393 - val_loss: 53.1725 - val_mean_absolute_error: 5.8351
# Epoch 76/100
# 7/7 [==============================] - 0s 13ms/step - loss: 246.4857 - mean_absolute_error: 12.7603 - val_loss: 47.6086 - val_mean_absolute_error: 5.5572
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 237.3485 - mean_absolute_error: 12.5686 - val_loss: 32.7172 - val_mean_absolute_error: 4.9181
# Epoch 78/100
# 7/7 [==============================] - 0s 16ms/step - loss: 202.1418 - mean_absolute_error: 11.6862 - val_loss: 43.7589 - val_mean_absolute_error: 5.4170
# Epoch 79/100
# 7/7 [==============================] - 0s 16ms/step - loss: 153.6231 - mean_absolute_error: 9.7354 - val_loss: 68.5072 - val_mean_absolute_error: 6.8385
# Epoch 80/100
# 7/7 [==============================] - 0s 16ms/step - loss: 137.3629 - mean_absolute_error: 9.1997 - val_loss: 80.5950 - val_mean_absolute_error: 7.5091
# Epoch 81/100
# 7/7 [==============================] - 0s 15ms/step - loss: 127.0921 - mean_absolute_error: 8.6931 - val_loss: 35.7431 - val_mean_absolute_error: 5.1292
# Epoch 82/100
# 7/7 [==============================] - 0s 13ms/step - loss: 109.2328 - mean_absolute_error: 8.0083 - val_loss: 41.7762 - val_mean_absolute_error: 5.3111
# Epoch 83/100
# 7/7 [==============================] - 0s 15ms/step - loss: 109.5941 - mean_absolute_error: 8.4473 - val_loss: 37.8495 - val_mean_absolute_error: 5.0275
# Epoch 84/100
# 7/7 [==============================] - 0s 15ms/step - loss: 81.6836 - mean_absolute_error: 6.9783 - val_loss: 48.8446 - val_mean_absolute_error: 5.5942
# Epoch 85/100
# 7/7 [==============================] - 0s 16ms/step - loss: 70.9425 - mean_absolute_error: 6.4735 - val_loss: 46.6730 - val_mean_absolute_error: 5.4280
# Epoch 86/100
# 7/7 [==============================] - 0s 14ms/step - loss: 59.0420 - mean_absolute_error: 5.8406 - val_loss: 48.3175 - val_mean_absolute_error: 5.4896
# Epoch 87/100
# 7/7 [==============================] - 0s 14ms/step - loss: 51.1079 - mean_absolute_error: 5.5273 - val_loss: 55.9638 - val_mean_absolute_error: 5.9446
# Epoch 88/100
# 7/7 [==============================] - 0s 17ms/step - loss: 49.4139 - mean_absolute_error: 5.5245 - val_loss: 44.1156 - val_mean_absolute_error: 5.2566
# Epoch 89/100
# 7/7 [==============================] - 0s 16ms/step - loss: 40.5695 - mean_absolute_error: 4.8300 - val_loss: 43.0330 - val_mean_absolute_error: 5.2131
# Epoch 90/100
# 7/7 [==============================] - 0s 15ms/step - loss: 37.9053 - mean_absolute_error: 4.6043 - val_loss: 55.8685 - val_mean_absolute_error: 5.8992
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 36.9241 - mean_absolute_error: 4.6875 - val_loss: 43.7183 - val_mean_absolute_error: 5.2677
# Epoch 92/100
# 7/7 [==============================] - 0s 14ms/step - loss: 33.3262 - mean_absolute_error: 4.5248 - val_loss: 31.3271 - val_mean_absolute_error: 4.7941
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 39.1251 - mean_absolute_error: 5.0283 - val_loss: 32.2819 - val_mean_absolute_error: 4.8148
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 34.7922 - mean_absolute_error: 4.7447 - val_loss: 31.3702 - val_mean_absolute_error: 4.7770
# Epoch 95/100
# 7/7 [==============================] - 0s 13ms/step - loss: 33.5256 - mean_absolute_error: 4.5849 - val_loss: 32.1382 - val_mean_absolute_error: 4.7964
# Epoch 96/100
# 7/7 [==============================] - 0s 11ms/step - loss: 29.6247 - mean_absolute_error: 4.3792 - val_loss: 37.8353 - val_mean_absolute_error: 4.9443
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 27.5929 - mean_absolute_error: 4.0554 - val_loss: 42.9751 - val_mean_absolute_error: 5.2702
# Epoch 98/100
# 7/7 [==============================] - 0s 14ms/step - loss: 26.7981 - mean_absolute_error: 4.0978 - val_loss: 52.0816 - val_mean_absolute_error: 5.7673
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 26.1005 - mean_absolute_error: 3.9880 - val_loss: 66.2658 - val_mean_absolute_error: 6.4424
# Epoch 100/100
# 7/7 [==============================] - 0s 14ms/step - loss: 26.0441 - mean_absolute_error: 3.9908 - val_loss: 44.7329 - val_mean_absolute_error: 5.3934

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

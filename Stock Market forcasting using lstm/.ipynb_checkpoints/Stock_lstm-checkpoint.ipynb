# %%
import pandas as pd
df=pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9465  2023-10-03  320.829987  321.390015  311.209991  313.390015  313.390015
# 9466  2023-10-04  314.029999  320.040009  314.000000  318.959991  318.959991
# 9467  2023-10-05  319.089996  319.980011  314.899994  319.359985  319.359985
# 9468  2023-10-06  316.549988  329.190002  316.299988  327.260010  327.260010
# 9469  2023-10-09  324.750000  330.299988  323.179993  329.820007  329.820007
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9465    21033500
# 9466    20720100
# 9467    16965600
# 9468    25645500
# 9469    19869600
#
# [9470 rows x 7 columns]

# %%
df =df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9465    2023-10-03
# 9466    2023-10-04
# 9467    2023-10-05
# 9468    2023-10-06
# 9469    2023-10-09
# Name: Date, Length: 9470, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9465  2023-10-03  313.390015
# 9466  2023-10-04  318.959991
# 9467  2023-10-05  319.359985
# 9468  2023-10-06  327.260010
# 9469  2023-10-09  329.820007
#
# [9470 rows x 2 columns]

# %%
df['Date']= df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\DEV\AppData\Local\Temp\ipykernel_15740\1066266531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9465   2023-10-03
# 9466   2023-10-04
# 9467   2023-10-05
# 9468   2023-10-06
# 9469   2023-10-09
# Name: Date, Length: 9470, dtype: datetime64[ns]

# %%
df.index=df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-03  313.390015
# 2023-10-04  318.959991
# 2023-10-05  319.359985
# 2023-10-06  327.260010
# 2023-10-09  329.820007
#
# [9470 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 147ms/step - loss: 84760.5547 - mean_absolute_error: 289.3965 - val_loss: 92341.9609 - val_mean_absolute_error: 303.7910
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 84370.1562 - mean_absolute_error: 288.7210 - val_loss: 91982.6797 - val_mean_absolute_error: 303.1991
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: 84035.9766 - mean_absolute_error: 288.1436 - val_loss: 91640.2969 - val_mean_absolute_error: 302.6340
# Epoch 4/100
# 7/7 [==============================] - 0s 18ms/step - loss: 83709.6641 - mean_absolute_error: 287.5752 - val_loss: 91285.5078 - val_mean_absolute_error: 302.0472
# Epoch 5/100
# 7/7 [==============================] - 0s 18ms/step - loss: 83347.9844 - mean_absolute_error: 286.9440 - val_loss: 90853.0312 - val_mean_absolute_error: 301.3305
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 82881.9141 - mean_absolute_error: 286.1284 - val_loss: 90237.7031 - val_mean_absolute_error: 300.3077
# Epoch 7/100
# 7/7 [==============================] - 0s 18ms/step - loss: 82217.7422 - mean_absolute_error: 284.9711 - val_loss: 89443.9219 - val_mean_absolute_error: 298.9832
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 81401.5000 - mean_absolute_error: 283.5341 - val_loss: 88439.1719 - val_mean_absolute_error: 297.2981
# Epoch 9/100
# 7/7 [==============================] - 0s 17ms/step - loss: 80378.5703 - mean_absolute_error: 281.7151 - val_loss: 87278.3828 - val_mean_absolute_error: 295.3395
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 79251.8047 - mean_absolute_error: 279.7084 - val_loss: 86002.3672 - val_mean_absolute_error: 293.1712
# Epoch 11/100
# 7/7 [==============================] - 0s 13ms/step - loss: 77880.0469 - mean_absolute_error: 277.2402 - val_loss: 84186.6016 - val_mean_absolute_error: 290.0577
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 75939.6641 - mean_absolute_error: 273.7281 - val_loss: 81994.6484 - val_mean_absolute_error: 286.2545
# Epoch 13/100
# 7/7 [==============================] - 0s 19ms/step - loss: 73894.5703 - mean_absolute_error: 269.9749 - val_loss: 79787.5781 - val_mean_absolute_error: 282.3732
# Epoch 14/100
# 7/7 [==============================] - 0s 23ms/step - loss: 71713.9922 - mean_absolute_error: 265.8839 - val_loss: 77258.6484 - val_mean_absolute_error: 277.8590
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 69151.9844 - mean_absolute_error: 261.0348 - val_loss: 74339.9453 - val_mean_absolute_error: 272.5564
# Epoch 16/100
# 7/7 [==============================] - 0s 11ms/step - loss: 66298.7578 - mean_absolute_error: 255.5372 - val_loss: 71109.6641 - val_mean_absolute_error: 266.5644
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 62918.0352 - mean_absolute_error: 248.7906 - val_loss: 66961.9375 - val_mean_absolute_error: 258.6676
# Epoch 18/100
# 7/7 [==============================] - 0s 15ms/step - loss: 58921.4609 - mean_absolute_error: 240.6017 - val_loss: 62527.7656 - val_mean_absolute_error: 249.9496
# Epoch 19/100
# 7/7 [==============================] - 0s 12ms/step - loss: 54696.2969 - mean_absolute_error: 231.6788 - val_loss: 58015.3516 - val_mean_absolute_error: 240.7538
# Epoch 20/100
# 7/7 [==============================] - 0s 14ms/step - loss: 50378.3750 - mean_absolute_error: 222.1856 - val_loss: 53288.7461 - val_mean_absolute_error: 230.7288
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 45908.8477 - mean_absolute_error: 211.8057 - val_loss: 48361.0469 - val_mean_absolute_error: 219.7910
# Epoch 22/100
# 7/7 [==============================] - 0s 12ms/step - loss: 41252.1445 - mean_absolute_error: 200.5480 - val_loss: 43313.0195 - val_mean_absolute_error: 207.9904
# Epoch 23/100
# 7/7 [==============================] - 0s 11ms/step - loss: 36478.3086 - mean_absolute_error: 188.2666 - val_loss: 38049.5352 - val_mean_absolute_error: 194.9266
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 31455.0801 - mean_absolute_error: 174.3760 - val_loss: 32503.1270 - val_mean_absolute_error: 180.1393
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 26568.5156 - mean_absolute_error: 159.9005 - val_loss: 27537.7344 - val_mean_absolute_error: 165.7853
# Epoch 26/100
# 7/7 [==============================] - 0s 14ms/step - loss: 22124.3848 - mean_absolute_error: 145.3525 - val_loss: 22842.1152 - val_mean_absolute_error: 150.9607
# Epoch 27/100
# 7/7 [==============================] - 0s 12ms/step - loss: 18023.8965 - mean_absolute_error: 130.4372 - val_loss: 18533.4219 - val_mean_absolute_error: 135.9428
# Epoch 28/100
# 7/7 [==============================] - 0s 11ms/step - loss: 14315.7988 - mean_absolute_error: 115.3750 - val_loss: 14657.8965 - val_mean_absolute_error: 120.8509
# Epoch 29/100
# 7/7 [==============================] - 0s 14ms/step - loss: 11093.4082 - mean_absolute_error: 100.2808 - val_loss: 11259.3516 - val_mean_absolute_error: 105.8602
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8347.2832 - mean_absolute_error: 85.2734 - val_loss: 8256.1846 - val_mean_absolute_error: 90.5698
# Epoch 31/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5935.1221 - mean_absolute_error: 69.9657 - val_loss: 5845.6602 - val_mean_absolute_error: 76.1097
# Epoch 32/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4188.1543 - mean_absolute_error: 56.3661 - val_loss: 4051.6689 - val_mean_absolute_error: 63.2353
# Epoch 33/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2940.3896 - mean_absolute_error: 44.8074 - val_loss: 2703.0996 - val_mean_absolute_error: 51.4795
# Epoch 34/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2076.2173 - mean_absolute_error: 36.7078 - val_loss: 1746.3634 - val_mean_absolute_error: 41.1509
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1532.1067 - mean_absolute_error: 32.2271 - val_loss: 1112.0956 - val_mean_absolute_error: 32.5443
# Epoch 36/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1235.7385 - mean_absolute_error: 29.6975 - val_loss: 708.5616 - val_mean_absolute_error: 25.6046
# Epoch 37/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1085.4500 - mean_absolute_error: 27.8706 - val_loss: 470.4182 - val_mean_absolute_error: 20.4317
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1037.0996 - mean_absolute_error: 27.2489 - val_loss: 335.9679 - val_mean_absolute_error: 16.8227
# Epoch 39/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1014.3792 - mean_absolute_error: 26.9197 - val_loss: 270.0211 - val_mean_absolute_error: 14.8120
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1013.3075 - mean_absolute_error: 26.9109 - val_loss: 247.0613 - val_mean_absolute_error: 14.0751
# Epoch 41/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1010.7546 - mean_absolute_error: 26.8794 - val_loss: 253.4527 - val_mean_absolute_error: 14.2844
# Epoch 42/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.3278 - mean_absolute_error: 26.8699 - val_loss: 266.2044 - val_mean_absolute_error: 14.6923
# Epoch 43/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.0813 - mean_absolute_error: 26.8598 - val_loss: 276.1127 - val_mean_absolute_error: 15.0009
# Epoch 44/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1010.4105 - mean_absolute_error: 26.8642 - val_loss: 276.1221 - val_mean_absolute_error: 15.0012
# Epoch 45/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1010.0414 - mean_absolute_error: 26.8594 - val_loss: 274.8133 - val_mean_absolute_error: 14.9608
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1010.7274 - mean_absolute_error: 26.8685 - val_loss: 262.9346 - val_mean_absolute_error: 14.5889
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.1689 - mean_absolute_error: 26.8615 - val_loss: 264.4798 - val_mean_absolute_error: 14.6379
# Epoch 48/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.5147 - mean_absolute_error: 26.8692 - val_loss: 260.9454 - val_mean_absolute_error: 14.5256
# Epoch 49/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1011.0731 - mean_absolute_error: 26.8839 - val_loss: 255.3799 - val_mean_absolute_error: 14.3469
# Epoch 50/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1009.8450 - mean_absolute_error: 26.8590 - val_loss: 263.1024 - val_mean_absolute_error: 14.5942
# Epoch 51/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.1357 - mean_absolute_error: 26.8590 - val_loss: 274.4700 - val_mean_absolute_error: 14.9502
# Epoch 52/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1010.0812 - mean_absolute_error: 26.8608 - val_loss: 278.1523 - val_mean_absolute_error: 15.0636
# Epoch 53/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.1456 - mean_absolute_error: 26.8603 - val_loss: 277.5912 - val_mean_absolute_error: 15.0464
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1010.0455 - mean_absolute_error: 26.8603 - val_loss: 278.5768 - val_mean_absolute_error: 15.0766
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.3577 - mean_absolute_error: 26.8456 - val_loss: 275.9382 - val_mean_absolute_error: 14.9990
# Epoch 56/100
# 7/7 [==============================] - 0s 12ms/step - loss: 997.7265 - mean_absolute_error: 26.6621 - val_loss: 300.0453 - val_mean_absolute_error: 15.7437
# Epoch 57/100
# 7/7 [==============================] - 0s 12ms/step - loss: 985.9838 - mean_absolute_error: 26.5371 - val_loss: 291.4050 - val_mean_absolute_error: 15.4837
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 974.5927 - mean_absolute_error: 26.3825 - val_loss: 323.3562 - val_mean_absolute_error: 16.4889
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 967.9920 - mean_absolute_error: 26.2550 - val_loss: 285.7972 - val_mean_absolute_error: 15.3268
# Epoch 60/100
# 7/7 [==============================] - 0s 12ms/step - loss: 959.0950 - mean_absolute_error: 26.1899 - val_loss: 316.4619 - val_mean_absolute_error: 16.2970
# Epoch 61/100
# 7/7 [==============================] - 0s 12ms/step - loss: 942.0045 - mean_absolute_error: 25.9278 - val_loss: 322.5176 - val_mean_absolute_error: 16.5008
# Epoch 62/100
# 7/7 [==============================] - 0s 13ms/step - loss: 917.6890 - mean_absolute_error: 25.5773 - val_loss: 298.4127 - val_mean_absolute_error: 15.7871
# Epoch 63/100
# 7/7 [==============================] - 0s 14ms/step - loss: 884.7145 - mean_absolute_error: 25.1480 - val_loss: 395.6010 - val_mean_absolute_error: 18.6349
# Epoch 64/100
# 7/7 [==============================] - 0s 12ms/step - loss: 865.8463 - mean_absolute_error: 24.8150 - val_loss: 221.8978 - val_mean_absolute_error: 13.3247
# Epoch 65/100
# 7/7 [==============================] - 0s 19ms/step - loss: 845.9512 - mean_absolute_error: 24.5801 - val_loss: 395.5974 - val_mean_absolute_error: 18.6815
# Epoch 66/100
# 7/7 [==============================] - 0s 12ms/step - loss: 819.6681 - mean_absolute_error: 24.0547 - val_loss: 173.7863 - val_mean_absolute_error: 11.5302
# Epoch 67/100
# 7/7 [==============================] - 0s 13ms/step - loss: 807.4745 - mean_absolute_error: 23.8992 - val_loss: 912.5012 - val_mean_absolute_error: 29.4215
# Epoch 68/100
# 7/7 [==============================] - 0s 14ms/step - loss: 985.4673 - mean_absolute_error: 26.5534 - val_loss: 228.2843 - val_mean_absolute_error: 13.5238
# Epoch 69/100
# 7/7 [==============================] - 0s 14ms/step - loss: 857.0107 - mean_absolute_error: 24.7575 - val_loss: 289.1307 - val_mean_absolute_error: 15.5878
# Epoch 70/100
# 7/7 [==============================] - 0s 17ms/step - loss: 809.9562 - mean_absolute_error: 23.8074 - val_loss: 183.2014 - val_mean_absolute_error: 11.9547
# Epoch 71/100
# 7/7 [==============================] - 0s 21ms/step - loss: 772.2636 - mean_absolute_error: 23.4838 - val_loss: 264.3502 - val_mean_absolute_error: 14.8384
# Epoch 72/100
# 7/7 [==============================] - 0s 12ms/step - loss: 735.8517 - mean_absolute_error: 22.9510 - val_loss: 154.2502 - val_mean_absolute_error: 10.8148
# Epoch 73/100
# 7/7 [==============================] - 0s 15ms/step - loss: 697.5406 - mean_absolute_error: 22.3288 - val_loss: 215.6692 - val_mean_absolute_error: 13.2414
# Epoch 74/100
# 7/7 [==============================] - 0s 19ms/step - loss: 649.2084 - mean_absolute_error: 21.3963 - val_loss: 240.0205 - val_mean_absolute_error: 14.1254
# Epoch 75/100
# 7/7 [==============================] - 0s 15ms/step - loss: 595.3945 - mean_absolute_error: 20.4636 - val_loss: 119.2656 - val_mean_absolute_error: 9.2808
# Epoch 76/100
# 7/7 [==============================] - 0s 16ms/step - loss: 564.1284 - mean_absolute_error: 20.1084 - val_loss: 174.9083 - val_mean_absolute_error: 11.8291
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 480.6776 - mean_absolute_error: 18.3708 - val_loss: 212.7225 - val_mean_absolute_error: 13.2818
# Epoch 78/100
# 7/7 [==============================] - 0s 15ms/step - loss: 441.7529 - mean_absolute_error: 17.3305 - val_loss: 242.7937 - val_mean_absolute_error: 14.4253
# Epoch 79/100
# 7/7 [==============================] - 0s 15ms/step - loss: 380.3784 - mean_absolute_error: 15.8959 - val_loss: 104.3133 - val_mean_absolute_error: 8.7145
# Epoch 80/100
# 7/7 [==============================] - 0s 15ms/step - loss: 285.3664 - mean_absolute_error: 13.8907 - val_loss: 50.0042 - val_mean_absolute_error: 5.6420
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 245.3514 - mean_absolute_error: 12.9670 - val_loss: 112.3131 - val_mean_absolute_error: 9.1497
# Epoch 82/100
# 7/7 [==============================] - 0s 17ms/step - loss: 241.5758 - mean_absolute_error: 13.0609 - val_loss: 155.8218 - val_mean_absolute_error: 11.2028
# Epoch 83/100
# 7/7 [==============================] - 0s 17ms/step - loss: 171.7794 - mean_absolute_error: 10.6470 - val_loss: 74.4173 - val_mean_absolute_error: 7.1846
# Epoch 84/100
# 7/7 [==============================] - 0s 13ms/step - loss: 148.6635 - mean_absolute_error: 9.5991 - val_loss: 32.1443 - val_mean_absolute_error: 4.8175
# Epoch 85/100
# 7/7 [==============================] - 0s 13ms/step - loss: 120.0836 - mean_absolute_error: 8.9410 - val_loss: 30.9606 - val_mean_absolute_error: 4.8260
# Epoch 86/100
# 7/7 [==============================] - 0s 15ms/step - loss: 77.0650 - mean_absolute_error: 6.9862 - val_loss: 30.8881 - val_mean_absolute_error: 4.8079
# Epoch 87/100
# 7/7 [==============================] - 0s 17ms/step - loss: 63.2427 - mean_absolute_error: 6.1132 - val_loss: 39.4258 - val_mean_absolute_error: 5.0450
# Epoch 88/100
# 7/7 [==============================] - 0s 15ms/step - loss: 46.4322 - mean_absolute_error: 5.1589 - val_loss: 31.9633 - val_mean_absolute_error: 4.8324
# Epoch 89/100
# 7/7 [==============================] - 0s 16ms/step - loss: 43.2762 - mean_absolute_error: 4.9531 - val_loss: 35.4287 - val_mean_absolute_error: 5.1223
# Epoch 90/100
# 7/7 [==============================] - 0s 15ms/step - loss: 41.4814 - mean_absolute_error: 5.1360 - val_loss: 66.0667 - val_mean_absolute_error: 6.4395
# Epoch 91/100
# 7/7 [==============================] - 0s 13ms/step - loss: 35.7617 - mean_absolute_error: 4.9015 - val_loss: 36.8072 - val_mean_absolute_error: 4.9144
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 32.9552 - mean_absolute_error: 4.5236 - val_loss: 36.9208 - val_mean_absolute_error: 5.1927
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.6364 - mean_absolute_error: 4.9108 - val_loss: 43.8816 - val_mean_absolute_error: 5.2967
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 31.0506 - mean_absolute_error: 4.4662 - val_loss: 61.6087 - val_mean_absolute_error: 6.1523
# Epoch 95/100
# 7/7 [==============================] - 0s 15ms/step - loss: 25.7503 - mean_absolute_error: 3.9781 - val_loss: 76.8265 - val_mean_absolute_error: 7.1029
# Epoch 96/100
# 7/7 [==============================] - 0s 13ms/step - loss: 32.4283 - mean_absolute_error: 4.5959 - val_loss: 38.2650 - val_mean_absolute_error: 4.9574
# Epoch 97/100
# 7/7 [==============================] - 0s 15ms/step - loss: 28.7297 - mean_absolute_error: 4.3560 - val_loss: 33.3508 - val_mean_absolute_error: 4.8520
# Epoch 98/100
# 7/7 [==============================] - 0s 14ms/step - loss: 27.9707 - mean_absolute_error: 4.3144 - val_loss: 36.7271 - val_mean_absolute_error: 4.8859
# Epoch 99/100
# 7/7 [==============================] - 0s 13ms/step - loss: 24.6109 - mean_absolute_error: 3.8242 - val_loss: 49.3412 - val_mean_absolute_error: 5.6414
# Epoch 100/100
# 7/7 [==============================] - 0s 13ms/step - loss: 21.0324 - mean_absolute_error: 3.6490 - val_loss: 77.1015 - val_mean_absolute_error: 7.1068

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
